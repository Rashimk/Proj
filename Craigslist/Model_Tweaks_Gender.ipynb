# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import seaborn as sns

import textacy

plt.style.use('fivethirtyeight')

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from sklearn.linear_model import LogisticRegression, LinearRegression
import statsmodels.api as sm

import pandas as pd, seaborn as sns, numpy as np, matplotlib.pyplot as plt

from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer, TfidfVectorizer 
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.learning_curve import learning_curve
from sklearn.cross_validation import train_test_split, cross_val_score, ShuffleSplit
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, GaussianNB

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score

from sklearn.pipeline import Pipeline

# %matplotlib inline

sns.set_style("darkgrid")
# Out:
# /Users/roshkhadka/anaconda/envs/dsi/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /Users/roshkhadka/anaconda/envs/dsi/lib/python2.7/site-packages/sklearn/learning_curve.py:23: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the functions are moved. This module will be removed in 0.20
#   DeprecationWarning)

# %%
df = pd.read_csv('../Data/df_cleaned.csv', encoding = 'utf-8')

# %%
def my_func(x):
    z = textacy.preprocess.normalize_whitespace(x)
    z = textacy.preprocess.preprocess_text(x, fix_unicode=True, lowercase=True, transliterate=False, no_urls=True, 
                                           no_emails=True, no_phone_numbers=True, no_numbers=True,
                                           no_currency_symbols=False, no_punct=True, no_contractions=False, 
                                           no_accents=True)
    doc = textacy.doc.Doc(z, lang=u'en')
    return doc

df['Body_doc'] = df['Body'].map(my_func)

# %% [markdown]
# ## Converting the documents bodies into appropriate categories:

# %%
import textacy
from textacy.extract import semistructured_statements as semistructured

# %% [markdown]
# ## finding the unique words that make each unique:

# %%
### for single words:

# %%
rms = [x.split() for x in df.Body_clean]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-35e2c464152f> in <module>()
# ----> 1 rms = [x.split() for x in df.Body_clean]
#
# NameError: name 'df' is not defined

# %%
df['Bolean'] = df['From'].map(lambda x: True if x == 'm' else False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-72f6c72612a5> in <module>()
# ----> 1 df['Bolean'] = df['From'].map(lambda x: True if x == 'm' else False)
#
# NameError: name 'df' is not defined

# %%
type_1 = textacy.keyterms.most_discriminating_terms(rms, bool_array_grp1 = df['Bolean'], max_n_terms=2500, top_n_terms=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e656cb7ea3fc> in <module>()
# ----> 1 type_1 = textacy.keyterms.most_discriminating_terms(rms, bool_array_grp1 = df['Bolean'], max_n_terms=2500, top_n_terms=100)
#
# NameError: name 'textacy' is not defined

# %%
type_1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5e582ee2e2b1> in <module>()
# ----> 1 type_1
#
# NameError: name 'type_1' is not defined

# %%
before_type2_1 = [x.to_bag_of_terms(ngrams=1, named_entities=True, lemmatize=False, as_strings=True) for x in df.Body_doc]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3970cfc8ba9d> in <module>()
# ----> 1 before_type2_1 = [x.to_bag_of_terms(ngrams=1, named_entities=True, lemmatize=False, as_strings=True) for x in df.Body_doc]
#
# NameError: name 'df' is not defined

# %%
before_type2_2 = [x.to_bag_of_terms(ngrams=2, named_entities=True, lemmatize=True, as_strings=True) for x in df.Body_doc]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e0afa5185b84> in <module>()
# ----> 1 before_type2_2 = [x.to_bag_of_terms(ngrams=2, named_entities=True, lemmatize=True, as_strings=True) for x in df.Body_doc]
#
# NameError: name 'df' is not defined

# %%
type_2_1 =  textacy.keyterms.most_discriminating_terms(before_type2_1, bool_array_grp1 = df['Bolean'], max_n_terms=2500, top_n_terms=100)

# %%
type_2_2 =  textacy.keyterms.most_discriminating_terms(before_type2_2, bool_array_grp1 = df['Bolean'], max_n_terms=2500, top_n_terms=100)

# %%
#  Without lemmeting type_2 and after lemmetingtype 2_1

# %%
body = [x.to_bag_of_words(lemmatize=True, as_strings=True).keys() for x in df.Body_doc]

# %%
rms.to_bay
# Out:
# ([u'eye contact',
#   u'locker room',
#   u'number pm',
#   u'not help',
#   u'afternoon',
#   u'beautiful woman',
#   u'steam room',
#   u'keep look',
#   u'black pant',
#   u'beautiful smile',
#   u'let meet',
#   u'face pic',
#   u'parking lot',
#   u'white guy',
#   u'nice look',
#   u'yoga pant',
#   u'long shoot',
#   u'beautiful girl',
#   u'tall guy',
#   u'preciousmi love',
#   u'exchange smile',
#   u'super hot',
#   u'hey man',
#   u'white male',
#   u'old guy',
#   u'numbernumber pm',
#   u'wear black',
#   u'absolutely beautiful',
#   u'hot tub',
#   u'young guy',
#   u'black guy',
#   u'think u',
#   u'grocery store',
#   u'look amazing',
#   u'light blue',
#   u'sunday afternoon',
#   u'interested tell',
#   u'la fitness',
#   u'thursday night',
#   u'wanna meet',
#   u'get dress',
#   u'latin guy',
#   u'color car',
#   u'morning preciousmi',
#   u'amazing smile',
#   u'big cock',
#   u'eye meet',
#   u'blonde girl',
#   u'numbernumber number',
#   u'cute girl',
# ...

# %%
feature = type_1[0] + type_1[1]

# %%
feature = [u'beautiful',
 u'cock',
 u'hit',
 u'hot',
 u'pants',
 u'black',
 u'locker',
 u'discreet',
 u'sauna',
 u'cum',
 u'interested',
 u'stunning',
 u'white',
 u'shorts',
 u'sucked',
 u'sexy',
 u'steam',
 u'latino',
 u'afternoon',
 u'lets',
 u'dick',
 u'guy',
 u'connect',
 u'nice',
 u'dressed',
 u'suck',
 u'eye',
 u'sucking',
 u'muscular',
 u'wearing',
 u'cashier',
 u'shower',
 u'shopping',
 u'legs',
 u'hairy',
 u'bulge',
 u'beach',
 u'car',
 u'buddy',
 u'counter',
 u'mall',
 u'masculine',
 u'mid',
 u'gym',
 u'jeans',
 u'checking',
 u'video',
 u'preciousmi',
 u'fun',
 u'incredible',
 u'waitress',
 u'load',
 u'publix',
 u'enjoyed',
 u'ass',
 u'station',
 u'petite',
 u'yo',
 u'lunch',
 u'sweat',
 u'stall',
 u'butt',
 u'starbucks',
 u'bro',
 u'foods',
 u'showered',
 u'bay',
 u'swing',
 u'tub',
 u'dinner',
 u'gorgeous',
 u'stroke',
 u'sub',
 u'smooth',
 u'tights',
 u'drop',
 u'suv',
 u'bump',
 u'theater',
 u'muscle',
 u'booth',
 u'hung',
 u'dude',
 u'older',
 u'discrete',
 u'purchase',
 u'heart',
 u'feel',
 u'all',
 u'never',
 u'my',
 u'because',
 u'things',
 u'that',
 u'life',
 u'still',
 u'only',
 u'him',
 u'will',
 u'his',
 u'he',
 u'just',
 u'have',
 u'happy',
 u'find',
 u'these',
 u'makes',
 u'hurt',
 u'always',
 u'myself',
 u'away',
 u'need',
 u'broken',
 u'everything',
 u'happiness',
 u'yourself',
 u'their',
 u'wont',
 u'feels',
 u'without',
 u'ever',
 u'truth',
 u'going',
 u'feeling',
 u'forget',
 u'part',
 u'relationship',
 u'make',
 u'miss',
 u'yet',
 u'move',
 u'making',
 u'believe',
 u'sad',
 u'bed',
 u'thank',
 u'beginning',
 u'hes',
 u'keep',
 u'promise',
 u'way',
 u'pain',
 u'trust']

# %%
seen = set()
features = []
for item in feature:
    if item not in seen:
        seen.add(item)
        features.append(item)

# %%
cv = CountVectorizer(vocabulary=features, binary= False, max_df=0.15, min_df = 1.0,
                     lowercase=True, strip_accents='unicode', stop_words='english', 
                     ngram_range=(1,1), max_features=2000, decode_error ='replace')

# %%
# need to use the lowercased texts
body_vec = cv.fit_transform([' '.join(x.to_bag_of_words(lemmatize=True, as_strings=True).keys())
                             for x in body])

# %%
# neaed to use the lowercased texts
# body_vec = cv.fit_transform(df['Body_clean'])

# %%
np.mean(body_vec, axis=0)
# Out:
# matrix([[ 0.09052478,  0.02755102,  0.05247813,  0.06253644,  0.        ,
#           0.09110787,  0.01049563,  0.01720117,  0.00874636,  0.00830904,
#           0.06516035,  0.00524781,  0.06443149,  0.        ,  0.        ,
#           0.04708455,  0.00641399,  0.00860058,  0.02084548,  0.        ,
#           0.01603499,  0.1303207 ,  0.02390671,  0.06618076,  0.00131195,
#           0.02827988,  0.13702624,  0.        ,  0.00641399,  0.        ,
#           0.00466472,  0.01501458,  0.00393586,  0.        ,  0.00408163,
#           0.00437318,  0.01472303,  0.05029155,  0.00874636,  0.00728863,
#           0.00553936,  0.00364431,  0.00539359,  0.01763848,  0.00029155,
#           0.00014577,  0.00393586,  0.003207  ,  0.0409621 ,  0.00655977,
#           0.003207  ,  0.00379009,  0.00291545,  0.00014577,  0.00072886,
#           0.01049563,  0.00466472,  0.0048105 ,  0.01778426,  0.00510204,
#           0.00393586,  0.00451895,  0.00597668,  0.00262391,  0.        ,
# ...

# %%
y = df.From_binary

# %%
Xtr, Xte, ytr, yte = train_test_split(body_vec, y, test_size=0.3)

# %%
rfc = RandomForestClassifier(max_features = None, min_samples_split = 128, n_estimators = 200, max_depth = None)

# %%
rfc.fit(Xtr, ytr)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=128, min_weight_fraction_leaf=0.0,
#             n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
np.mean(yte)
# Out:
# 0.8338192419825073

# %%
rfc.score(Xte, yte)
# Out:
# 0.83041788143828965

# %%
seen = set()
features = []
for item in feature:
    if item not in seen:
        seen.add(item)
        features.append(item)

# %%
cv = CountVectorizer(vocabulary=features, binary= True,
                     lowercase=True, strip_accents='unicode', stop_words='english', 
                     ngram_range=(1,1), max_features=2000, decode_error ='replace')

# %%
# need to use the lowercased texts
body_vec = cv.fit_transform(df['Body_clean'])

# %%
body = [x.to_bag_of_words(lemmatize=True, as_strings=True).keys() for x in df.Body_doc]

# %%
body = df.Body_doc

# %%
# need to use the lowercased texts
body_vec = cv.fit_transform([' '.join(x.to_bag_of_words(lemmatize=True, as_strings=True).keys())
                             for x in body])

# %%
np.mean(body_vec, axis=0)
# Out:
# matrix([[  9.05247813e-02,   2.75510204e-02,   5.24781341e-02,
#            6.25364431e-02,   0.00000000e+00,   9.11078717e-02,
#            1.04956268e-02,   1.72011662e-02,   8.74635569e-03,
#            8.30903790e-03,   2.74052478e-02,   6.51603499e-02,
#            5.24781341e-03,   6.44314869e-02,   0.00000000e+00,
#            7.14285714e-03,   0.00000000e+00,   5.69970845e-02,
#            4.70845481e-02,   6.41399417e-03,   8.60058309e-03,
#            2.08454810e-02,   0.00000000e+00,   1.60349854e-02,
#            1.30320700e-01,   2.39067055e-02,   6.61807580e-02,
#            1.09329446e-02,   1.31195335e-03,   2.82798834e-02,
#            1.67784257e-01,   1.37026239e-01,   4.95626822e-03,
#            0.00000000e+00,   6.41399417e-03,   0.00000000e+00,
#            4.66472303e-03,   1.50145773e-02,   3.93586006e-03,
#            0.00000000e+00,   4.08163265e-03,   4.37317784e-03,
#            1.47230321e-02,   5.02915452e-02,   8.74635569e-03,
# ...

# %%
y = df.From_binary

# %%
Xtr, Xte, ytr, yte = train_test_split(body_vec, y, test_size=0.3)

# %%
rf_params = {'max_depth': [2, 3, 4, 5, 6, None],
 'max_features': [None, 'sqrt', 'log2'],
 'min_samples_split': [2, 4, 8, 16, 32, 64, 128],
 'n_estimators': [200]}

# %%
rf = RandomForestClassifier()
rf_gs = GridSearchCV(rf, rf_params, cv=5, verbose=2, n_jobs=-1)
rf_gs.fit(body_vec, y)
# Out:
# Fitting 5 folds for each of 126 candidates, totalling 630 fits
# [CV] max_features=None, min_samples_split=2, n_estimators=200, max_depth=2
# [CV] max_features=None, min_samples_split=2, n_estimators=200, max_depth=2
# [CV] max_features=None, min_samples_split=2, n_estimators=200, max_depth=2
# [CV] max_features=None, min_samples_split=2, n_estimators=200, max_depth=2
# [CV]  max_features=None, min_samples_split=2, n_estimators=200, max_depth=2, total=   2.1s
# [CV] max_features=None, min_samples_split=2, n_estimators=200, max_depth=2
# [CV]  max_features=None, min_samples_split=2, n_estimators=200, max_depth=2, total=   2.1s
# [CV]  max_features=None, min_samples_split=2, n_estimators=200, max_depth=2, total=   2.1s
# [CV] max_features=None, min_samples_split=4, n_estimators=200, max_depth=2
# [CV] max_features=None, min_samples_split=4, n_estimators=200, max_depth=2
# [CV]  max_features=None, min_samples_split=2, n_estimators=200, max_depth=2, total=   2.2s
# ...

# %%
print rf_gs.best_params_
print rf_gs.best_score_
rf_best = rf_gs.best_estimator_
# Out:
# {'max_features': None, 'min_samples_split': 128, 'n_estimators': 200, 'max_depth': None}
# 0.830903790087

# %%
rfc = RandomForestClassifier(max_features = None, min_samples_split = 128, n_estimators = 200, max_depth = None)

# %%
rfc.fit(Xtr, ytr)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features=None, max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=128, min_weight_fraction_leaf=0.0,
#             n_estimators=200, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False)

# %%
np.mean(yte)
# Out:
# 0.8206997084548106

# %%
rfc.score(Xte, yte)
# Out:
# 0.82410106899902813

# %%
body_docs = [textacy.doc.Doc(x, lang=u'en') for x in body]

# %%
type_2 = [x.to_bag_of_terms(ngrams=2, named_entities=True,
                          lemmatize=True, as_strings=True) for x in body_docs]

# %%
type_3 = textacy.keyterms.most_discriminating_terms(type_2, bool_array_grp1 = df['Bolean'], max_n_terms=5000, top_n_terms=80)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-b9b392af7e83> in <module>()
# ----> 1 type_3 = textacy.keyterms.most_discriminating_terms(type_2, bool_array_grp1 = df['Bolean'], max_n_terms=5000, top_n_terms=80)
#
# /Users/roshkhadka/anaconda/envs/dsi/lib/python2.7/site-packages/textacy/keyterms.pyc in most_discriminating_terms(terms_lists, bool_array_grp1, max_n_terms, top_n_terms)
#     360     for idx, term_id in enumerate(term_ids_grp1):
#     361         term1 = Decimal(math.factorial(grp1_terms_grp1_df[idx] + alpha_grp1 - 1)) * Decimal(math.factorial(grp1_terms_grp2_df[idx] + alpha_grp2 - 1)) / Decimal(math.factorial(grp1_terms_grp1_df[idx] + grp1_terms_grp2_df[idx] + alpha_grp1 + alpha_grp2 - 1))
# ...

# %%
age = []
for i in range(df.shape[0]):
    if df.Age[i] >= 18 and df.Age[i] <= 25:
        age.append(0)
    elif df.Age[i] > 25 and df.Age[i] <=40:
        age.append(1)
    elif df.Age[i] > 40:
        age.append(2)

# %%
type(df.Body_doc[0])
print(doc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-628-a0bac0418f8c> in <module>()
#       1 type(df.Body_doc[0])
# ----> 2 print(doc)
#
# NameError: name 'doc' is not defined

# %%
body = [x.to_bag_of_words(lemmatize=True, as_strings=True).keys() for x in df.Body_doc]
