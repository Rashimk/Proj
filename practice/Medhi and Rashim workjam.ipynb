# %%
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


sns.set_style('darkgrid')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

coffee_file = '/Users/roshkhadka/Desktop/DSI-SF-4-Rashimk/datasets/coffee_preferences/coffee-preferences.csv'
df = pd.read_csv(coffee_file)

# %%
df.head()
# Out:
#             Timestamp     Name  Starbucks  PhilzCoffee  BlueBottleCoffee  \
# 0  3/17/2015 18:37:58   Alison          3            5               4.0
# 1  3/17/2015 18:38:09    April          4            5               5.0
# 2  3/17/2015 18:38:25    Vijay          3            5               5.0
# 3  3/17/2015 18:38:28  Vanessa          1            5               5.0
# 4  3/17/2015 18:38:46   Isabel          1            4               4.0
#
#    PeetsTea  CaffeTrieste  GrandCoffee  RitualCoffee  FourBarrel  WorkshopCafe
# 0       3.0           NaN          NaN           5.0         5.0           NaN
# 1       3.0           NaN          NaN           3.0         NaN           5.0
# 2       5.0           3.0          2.0           1.0         1.0           1.0
# 3       2.0           NaN          NaN           3.0         2.0           3.0
# 4       2.0           4.0          NaN           4.0         4.0           NaN

# %%
df.isnull().sum()  ##Checking
# Out:
# Timestamp            0
# Name                 0
# Starbucks            0
# PhilzCoffee          0
# BlueBottleCoffee     6
# PeetsTea             1
# CaffeTrieste        12
# GrandCoffee         15
# RitualCoffee         7
# FourBarrel          10
# WorkshopCafe         8
# dtype: int64

# %%
plt.

# %%
df = df.fillna(0)

# df.replace(np.nan, 0)

# %%
df["Timestamp"] = pd.to_datetime(df["Timestamp"])

df.insert(1,"year",df["Timestamp"].dt.year)
df
# Out:
#              Timestamp  year              Name  Starbucks  PhilzCoffee  \
# 0  2015-03-17 18:37:58  2015            Alison          3            5
# 1  2015-03-17 18:38:09  2015             April          4            5
# 2  2015-03-17 18:38:25  2015             Vijay          3            5
# 3  2015-03-17 18:38:28  2015           Vanessa          1            5
# 4  2015-03-17 18:38:46  2015            Isabel          1            4
# 5  2015-03-17 18:39:01  2015             India          5            3
# 6  2015-03-17 18:39:01  2015            Dave H          4            5
# 7  2015-03-17 18:39:05  2015           Deepthi          3            5
# 8  2015-03-17 18:39:14  2015            Ramesh          3            4
# 9  2015-03-17 18:39:23  2015         Hugh Jass          1            5
# 10 2015-03-17 18:39:23  2015              Alex          4            5
# 11 2015-03-17 18:39:30  2015        Ajay Anand          3            4
# ...

# %%
df_t= df.transpose()
df_t
# Out:
#                                    0                    1   \
# Timestamp         2015-03-17 18:37:58  2015-03-17 18:38:09
# year                             2015                 2015
# Name                           Alison                April
# Starbucks                           3                    4
# PhilzCoffee                         5                    5
# BlueBottleCoffee                    4                    5
# PeetsTea                            3                    3
# CaffeTrieste                        0                    0
# GrandCoffee                         0                    0
# RitualCoffee                        5                    3
# FourBarrel                          5                    0
# WorkshopCafe                        0                    5
#
#                                    2                    3   \
# Timestamp         2015-03-17 18:38:25  2015-03-17 18:38:28
# year                             2015                 2015
# ...

# %%
# new_df = df.drop(['Timestamp', 'year', 'Name'], 0)

# %%
df_t['Average'] = new_df.mean(axis=1)

# %%
df
# Out:
#              Timestamp  year              Name  Starbucks  PhilzCoffee  \
# 0  2015-03-17 18:37:58  2015            Alison          3            5
# 1  2015-03-17 18:38:09  2015             April          4            5
# 2  2015-03-17 18:38:25  2015             Vijay          3            5
# 3  2015-03-17 18:38:28  2015           Vanessa          1            5
# 4  2015-03-17 18:38:46  2015            Isabel          1            4
# 5  2015-03-17 18:39:01  2015             India          5            3
# 6  2015-03-17 18:39:01  2015            Dave H          4            5
# 7  2015-03-17 18:39:05  2015           Deepthi          3            5
# 8  2015-03-17 18:39:14  2015            Ramesh          3            4
# 9  2015-03-17 18:39:23  2015         Hugh Jass          1            5
# 10 2015-03-17 18:39:23  2015              Alex          4            5
# 11 2015-03-17 18:39:30  2015        Ajay Anand          3            4
# ...

# %%
df.head(2)
# Out:
#             Timestamp  year    Name  Starbucks  PhilzCoffee  BlueBottleCoffee  \
# 0 2015-03-17 18:37:58  2015  Alison          3            5               4.0
# 1 2015-03-17 18:38:09  2015   April          4            5               5.0
#
#    PeetsTea  CaffeTrieste  GrandCoffee  RitualCoffee  FourBarrel  WorkshopCafe
# 0       3.0           0.0          0.0           5.0         5.0           0.0
# 1       3.0           0.0          0.0           3.0         0.0           5.0

# %%
table = pd.pivot_table(df, index=['Starbucks', 'PhilzCoffee', 'BlueBottleCoffee','PeetsTea'])

# %%
table
# Out:
#                                                  CaffeTrieste  FourBarrel  \
# Starbucks PhilzCoffee BlueBottleCoffee PeetsTea
# 1         4           4.0              2.0           4.000000         4.0
#           5           3.0              2.0           0.000000         3.0
#                       5.0              2.0           0.000000         2.0
#                                        4.0           5.000000         4.0
# 2         3           4.0              2.0           2.000000         4.0
# 3         1           0.0              0.0           0.000000         0.0
#           4           0.0              3.0           0.000000         0.0
#                       4.0              3.0           2.500000         0.0
#           5           0.0              2.0           0.000000         0.0
#                                        3.0           0.000000         0.0
#                       4.0              3.0           1.666667         4.0
# ...
